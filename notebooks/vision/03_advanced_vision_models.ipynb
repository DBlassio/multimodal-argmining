# %% [markdown]
# ### Notebook 03: Finetune Advanced Vision Models (CLIP, ViT, BLIP, ALIGN)
#
# As we moved towards multimodality we want to acquire experience and intuition on modern vision models. These models were trained with text + images so they will have better performance with memes, screenshots, visual cues, etc. As we saw in our EDA notebook, many of our images have text that could be relevant to our classifications.
#
# This notebook covers the full preprocessing pipeline and training for Modern Vision Models for **Stance Classification** (support/oppose).
#
# Images are resized, normalized, and batched. Models are fine-tuned with cross-entropy loss and evaluated on our goal metric - F1-Score (Binary).
#
# ## Models tested:
# - **CLIP** (OpenAI) - Trained on 400M image-text pairs, ideal for memes
# - **Vision Transformer (ViT)** - State-of-the-art for image classification
# - **BLIP** (Salesforce) - Trained for image-text matching and captioning
# - **ALIGN** (Google/Kakaobrain) - Large-scale image-text alignment
#
# **Goal:** Find the best vision encoder for multimodal fusion by benchmarking all candidates.

# %%
# Libraries
import os
import sys
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from tqdm.auto import tqdm
from transformers import CLIPProcessor, CLIPModel,ViTImageProcessor, ViTForImageClassification,BlipProcessor, BlipModel, AlignProcessor, AlignModel,get_linear_schedule_with_warmup
import warnings
warnings.filterwarnings("ignore")

# Random seed for reproducibility
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(SEED)

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Seed:  {SEED}")
print(f"Using device: {device}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Seed:  42
# Using device: cuda
# GPU: NVIDIA H100 NVL

# %%
# Paths
os.chdir("/workspace/dzuniga/multimodal-argmining")
DATA_PATH   = "data/"
IMG_PATH    = "data/images"
OUTPUT_DIR  = "results/vision/advanced_vision_models/"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Load Dataset
df_train = pd.read_csv(os.path.join(DATA_PATH, "train_with_captions.csv"))
df_dev   = pd.read_csv(os.path.join(DATA_PATH, "dev_with_captions.csv"))
df_test  = pd.read_csv(os.path.join(DATA_PATH, "test_with_captions.csv"))

# Map labels
stance_2id = {"oppose": 0, "support": 1}

for df in [df_train, df_dev, df_test]:
    df["label"] = df["stance"].map(stance_2id)

print(f"Train: {len(df_train)} | Dev: {len(df_dev)} | Test: {len(df_test)}")
print(f"\nTrain Stance:\n{df_train['stance'].value_counts()}")
print(f"\nDev Stance:\n{df_dev['stance'].value_counts()}")
print(f"\nTest Stance:\n{df_test['stance'].value_counts()}")
# Out:
# Train: 2190 | Dev: 200 | Test: 300
#
# Train Stance:
# stance
# support    1095
# oppose     1095
# Name: count, dtype: int64
#
# Dev Stance:
# stance
# oppose     127
# support     73
# Name: count, dtype: int64
#
# Test Stance:
# stance
# oppose     182
# support    118
# Name: count, dtype: int64

# %%
# Model names
CLIP_MODEL  = "openai/clip-vit-base-patch32"
VIT_MODEL   = "google/vit-base-patch16-224"
BLIP_MODEL  = "Salesforce/blip-itm-base-coco"
ALIGN_MODEL = "kakaobrain/align-base"

print("Models to benchmark:")
print(f"  1. CLIP:  {CLIP_MODEL}")
print(f"  2. ViT:   {VIT_MODEL}")
print(f"  3. BLIP:  {BLIP_MODEL}")
print(f"  4. ALIGN: {ALIGN_MODEL}")
# Out:
# Models to benchmark:
#   1. CLIP:  openai/clip-vit-base-patch32
#   2. ViT:   google/vit-base-patch16-224
#   3. BLIP:  Salesforce/blip-itm-base-coco
#   4. ALIGN: kakaobrain/align-base

# %%
# Training Hyperparameters
BATCH_SIZE    = 16
NUM_EPOCHS    = 10
LEARNING_RATE = 2e-5
WEIGHT_DECAY  = 1e-4
WARMUP_RATIO  = 0.1
PATIENCE      = 3
NUM_WORKERS   = 1

print(f"\nTraining config:")
print(f"  Batch size: {BATCH_SIZE}")
print(f"  Epochs: {NUM_EPOCHS}")
print(f"  Learning rate: {LEARNING_RATE}")
print(f"  Patience: {PATIENCE}")
# Out:
# Training config:
#   Batch size: 16
#   Epochs: 10
#   Learning rate: 2e-05
#   Patience: 3

# %%
class VisionDataset(Dataset):
    def __init__(self, dataframe, image_dir, processor):
        self.df = dataframe.reset_index(drop=True)
        self.image_dir = image_dir
        self.processor = processor
        
        # Image paths
        self.df['_image_path'] = self.df['tweet_id'].apply(lambda x: os.path.join(image_dir, f"{x}.jpg"))
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        
        # Load image
        try:
            image = Image.open(row['_image_path']).convert('RGB')
        except Exception as e:
            # Fallback to blank image if loading fails
            image = Image.new('RGB', (224, 224), color=(128, 128, 128))
        
        label = row['label']
        
        return {
            'image': image,
            'label': torch.tensor(label, dtype=torch.long),
            'tweet_id': row['tweet_id']
        }


def custom_collate_fn(batch, processor):
    images    = [item['image'] for item in batch]
    labels    = torch.stack([item['label'] for item in batch])
    tweet_ids = [item['tweet_id'] for item in batch]
    
    # Process images with the model-specific processor
    processed = processor(images=images, return_tensors="pt")
    
    return {
        'pixel_values': processed['pixel_values'],
        'labels': labels,
        'tweet_ids': tweet_ids
    }

print(" Dataset and collate function defined")
# Out:
#  Dataset and collate function defined

# %% [markdown]
# ### 5.1 CLIP Model
#
# **Why CLIP?**
# - Trained on 400M image-text pairs
# - Understands text IN images (perfect for memes/posters)
# - Better semantic understanding than pure vision models

# %%
class CLIPClassifier(nn.Module):
    """
    Architecture: CLIP Vision Encoder → Classifier Head
    """
    
    def __init__(self, model_name="openai/clip-vit-base-patch32", num_classes=2, freeze_encoder=True):
        super(CLIPClassifier, self).__init__()
        
        self.clip = CLIPModel.from_pretrained(model_name)
        self.vision_model = self.clip.vision_model
        
        # Partial freeze: unfreeze last layer only
        if freeze_encoder:
            for param in self.vision_model.parameters():
                param.requires_grad = False
            for name, param in self.vision_model.named_parameters():
                if "encoder.layers.11" in name:
                    param.requires_grad = True
            print("  CLIP encoder partially frozen (last layer + classifier trainable)")
        
        hidden_dim = self.clip.config.projection_dim  # 512
        
        self.classifier = nn.Sequential(
            nn.Dropout(0.3),
            nn.Linear(hidden_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, num_classes)
        )
        
        print(f"  CLIP initialized: hidden_dim={hidden_dim} | num_classes={num_classes}")
    
    def forward(self, pixel_values):
        vision_outputs = self.vision_model(pixel_values=pixel_values)
        cls_embedding  = vision_outputs.last_hidden_state[:, 0, :]
        pooled_output  = self.clip.visual_projection(cls_embedding)
        logits = self.classifier(pooled_output)
        return logits

print(" CLIPClassifier defined")
# Out:
#  CLIPClassifier defined

# %% [markdown]
# ### ViT Model
#
# **Why ViT?**
# - Pure transformer architecture for vision
# - State-of-the-art on ImageNet
# - Strong baseline for image-only classification

# %%
class ViTClassifier(nn.Module):
    """
    ViT-based stance classifier.
    Uses HuggingFace's ViTForImageClassification with custom head.
    """
    
    def __init__(self, model_name="google/vit-base-patch16-224", num_classes=2, freeze_encoder=True):
        super(ViTClassifier, self).__init__()
        
        self.vit = ViTForImageClassification.from_pretrained(model_name,num_labels=num_classes,ignore_mismatched_sizes=True)
        
        if freeze_encoder:
            for param in self.vit.vit.parameters():
                param.requires_grad = False
            # Unfreeze last encoder layer
            for param in self.vit.vit.encoder.layer[-1].parameters():
                param.requires_grad = True
            print("  ViT encoder partially frozen (last layer + classifier trainable)")
        
        print(f"  ViT initialized: num_classes={num_classes}")
    
    def forward(self, pixel_values):
        outputs = self.vit(pixel_values=pixel_values)
        return outputs.logits

print(" ViTClassifier defined")
# Out:
#  ViTClassifier defined

# %% [markdown]
# ### BLIP Model
#
# **Why BLIP?**
# - Trained for image-text matching (BLIP-ITM)
# - Better at understanding image-text relationships
# - Ideal for ironic/implicit content in memes

# %%
class BLIPClassifier(nn.Module):
    """
    Architecture: BLIP Vision Encoder → Classifier Head
    """
    
    def __init__(self, model_name="Salesforce/blip-itm-base-coco", num_classes=2, freeze_encoder=True):
        super(BLIPClassifier, self).__init__()
        
        blip_full = BlipModel.from_pretrained(model_name)
        self.vision_model = blip_full.vision_model
        hidden_dim = blip_full.config.vision_config.hidden_size  # 768
        
        # Partial freeze: unfreeze last layer only
        if freeze_encoder:
            for param in self.vision_model.parameters():
                param.requires_grad = False
            # Unfreeze last encoder layer
            for name, param in self.vision_model.named_parameters():
                if "encoder.layers.11" in name:
                    param.requires_grad = True
            print("  BLIP encoder partially frozen (last layer + classifier trainable)")
        
        self.classifier = nn.Sequential(
            nn.Dropout(0.3),
            nn.Linear(hidden_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, num_classes))
        
        print(f"  BLIP initialized: hidden_dim={hidden_dim} | num_classes={num_classes}")
    
    def forward(self, pixel_values):
        vision_outputs = self.vision_model(pixel_values=pixel_values)
        pooled_output  = vision_outputs.pooler_output  # [batch, 768]
        logits = self.classifier(pooled_output)
        return logits

print(" BLIPClassifier defined")
# Out:
#  BLIPClassifier defined

# %% [markdown]
# ### ALIGN Model
#
# **Why ALIGN?**
# - Trained on 1.8B image-text pairs (noisy data)
# - Large-scale contrastive learning
# - Strong generalization to out-of-domain content

# %%
class ALIGNClassifier(nn.Module):
    """
    Architecture: ALIGN Vision Encoder → Classifier Head
    """
    
    def __init__(self, model_name="kakaobrain/align-base", num_classes=2, freeze_encoder=True):
        super(ALIGNClassifier, self).__init__()
        
        align_full = AlignModel.from_pretrained(model_name)
        self.vision_model = align_full.vision_model
        hidden_dim = align_full.config.vision_config.hidden_dim  # 640
        
        # Partial freeze: unfreeze last layer only
        if freeze_encoder:
            for param in self.vision_model.parameters():
                param.requires_grad = False
            # Unfreeze last encoder layer
            for name, param in self.vision_model.named_parameters():
                if "encoder.stages.3" in name:
                    param.requires_grad = True
            print("  ALIGN encoder partially frozen (last stage + classifier trainable)")
        
        self.classifier = nn.Sequential(
            nn.Dropout(0.3),
            nn.Linear(hidden_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, num_classes)
        )
        
        print(f"  ALIGN initialized: hidden_dim={hidden_dim} | num_classes={num_classes}")
    
    def forward(self, pixel_values):
        vision_outputs = self.vision_model(pixel_values=pixel_values)
        pooled_output  = vision_outputs.pooler_output  # [batch, 640]
        logits = self.classifier(pooled_output)
        return logits

print(" ALIGNClassifier defined")
# Out:
#  ALIGNClassifier defined

# %% [markdown]
# ### Training and Evaluation Functions

# %%
def train_vision_model(model, processor, train_df, dev_df,
                       num_epochs=10, learning_rate=2e-5, batch_size=16, device=device):
    """
    Train vision model (CLIP, ViT, BLIP, or ALIGN) for stance classification.
    """
    
    print(f"\nTraining Stance Classification")
    
    # Datasets
    train_dataset = VisionDataset(train_df, IMG_PATH, processor)
    dev_dataset   = VisionDataset(dev_df, IMG_PATH, processor)
    
    # DataLoaders with custom collate
    train_loader = DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True, num_workers=NUM_WORKERS,
        collate_fn=lambda batch: custom_collate_fn(batch, processor), pin_memory=True)
    
    dev_loader = DataLoader(
        dev_dataset, batch_size=batch_size, shuffle=False, num_workers=NUM_WORKERS,
        collate_fn=lambda batch: custom_collate_fn(batch, processor), pin_memory=True)
    
    print(f"  Train batches: {len(train_loader)} | Dev batches: {len(dev_loader)}")
    
    model = model.to(device)
    
    # Loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=WEIGHT_DECAY)
    
    # Scheduler with warmup
    num_training_steps = len(train_loader) * num_epochs
    num_warmup_steps   = int(num_training_steps * WARMUP_RATIO)
    scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=num_warmup_steps, num_training_steps=num_training_steps)
    
    # Training history
    history = {'train_loss': [], 'dev_f1': [], 'dev_loss': [], 'learning_rates': []}
    
    # Early stopping
    best_f1 = 0.0
    best_model_state = None
    patience_counter = 0
    
    # Training loop
    for epoch in range(num_epochs):
        print(f"\nEpoch {epoch + 1}/{num_epochs}")
        print("-" * 50)
        
        # === TRAINING ===
        model.train()
        train_loss = 0.0
        
        pbar = tqdm(train_loader, desc="Training", leave=False)
        for batch in pbar:
            pixel_values = batch['pixel_values'].to(device)
            labels = batch['labels'].to(device)
            
            logits = model(pixel_values)
            loss = criterion(logits, labels)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            scheduler.step()
            
            train_loss += loss.item() * pixel_values.size(0)
            pbar.set_postfix({'loss': f"{loss.item():.4f}"})
        
        train_loss = train_loss / len(train_dataset)
        
        # === VALIDATION ===
        model.eval()
        dev_loss = 0.0
        all_preds, all_labels = [], []
        
        with torch.no_grad():
            for batch in tqdm(dev_loader, desc="Validation", leave=False):
                pixel_values = batch['pixel_values'].to(device)
                labels = batch['labels'].to(device)
                
                logits = model(pixel_values)
                loss = criterion(logits, labels)
                
                dev_loss += loss.item() * pixel_values.size(0)
                preds = torch.argmax(logits, dim=1)
                
                all_preds.extend(preds.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())
        
        dev_loss = dev_loss / len(dev_dataset)
        dev_f1   = f1_score(all_labels, all_preds, average='binary', pos_label=1, zero_division=0)
        
        # Save history
        current_lr = optimizer.param_groups[0]['lr']
        history['train_loss'].append(train_loss)
        history['dev_f1'].append(dev_f1)
        history['dev_loss'].append(dev_loss)
        history['learning_rates'].append(current_lr)
        
        print(f"  Train Loss: {train_loss:.4f}")
        print(f"  Dev Loss: {dev_loss:.4f} | Dev F1: {dev_f1:.4f} | LR: {current_lr:.2e}")
        
        # Early stopping
        if dev_f1 > best_f1:
            best_f1 = dev_f1
            best_model_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
            patience_counter = 0
            print(f"   New best F1: {best_f1:.4f}")
        else:
            patience_counter += 1
            print(f"  No improvement ({patience_counter}/{PATIENCE})")
            
            if patience_counter >= PATIENCE:
                print(f"  Early stopping at epoch {epoch + 1}")
                break
    
    # Load best model
    model.load_state_dict(best_model_state)
    model = model.to(device)
    
    print(f"\n Training complete! Best F1: {best_f1:.4f}")
    
    return model, history

print("train_vision_model function defined")
# Out:
# train_vision_model function defined

# %%
def evaluate_vision_model(model, processor, test_df, device=device):
    """
    Evaluate vision model on test set.
    """
    test_dataset = VisionDataset(test_df, IMG_PATH, processor)
    test_loader  = DataLoader(
        test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS,
        collate_fn=lambda batch: custom_collate_fn(batch, processor))
    
    model.eval()
    all_preds, all_labels = [], []
    
    with torch.no_grad():
        for batch in tqdm(test_loader, desc="Testing", leave=False):
            pixel_values = batch['pixel_values'].to(device)
            labels = batch['labels'].to(device)
            
            logits = model(pixel_values)
            preds = torch.argmax(logits, dim=1)
            
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    # Calculate metrics
    f1   = f1_score(all_labels, all_preds, average='binary', pos_label=1)
    acc  = accuracy_score(all_labels, all_preds)
    prec = precision_score(all_labels, all_preds, average='binary', pos_label=1, zero_division=0)
    rec  = recall_score(all_labels, all_preds, average='binary', pos_label=1)
    cm   = confusion_matrix(all_labels, all_preds)
    
    return {
        'f1': f1,
        'accuracy': acc,
        'precision': prec,
        'recall': rec,
        'confusion_matrix': cm,
        'y_true': np.array(all_labels),
        'y_pred': np.array(all_preds)
    }

print(" evaluate_vision_model function defined")
# Out:
#  evaluate_vision_model function defined

# %% [markdown]
# ## Model Benchmarking
#
# We'll train and evaluate all 4 models for stance classification.

# %%
# Storage for all results
all_results = []
all_histories = {}

# %% [markdown]
# ### Model 1: CLIP

# %%
print("MODEL 1: CLIP")

clip_processor = CLIPProcessor.from_pretrained(CLIP_MODEL)
clip_model = CLIPClassifier(model_name=CLIP_MODEL, num_classes=2, freeze_encoder=True)

print(f"  Total params: {sum(p.numel() for p in clip_model.parameters()):,}")
print(f"  Trainable:    {sum(p.numel() for p in clip_model.parameters() if p.requires_grad):,}")

trained_clip, clip_history = train_vision_model(
    clip_model, clip_processor, df_train, df_dev,
    num_epochs=NUM_EPOCHS, learning_rate=LEARNING_RATE, batch_size=BATCH_SIZE)

clip_results = evaluate_vision_model(trained_clip, clip_processor, df_test)

all_results.append({'Model': 'CLIP', **clip_results})
all_histories['CLIP'] = clip_history

print(f"\n CLIP Results:")
print(f"  Test F1:        {clip_results['f1']:.4f}")
print(f"  Test Accuracy:  {clip_results['accuracy']:.4f}")
print(f"  Test Precision: {clip_results['precision']:.4f}")
print(f"  Test Recall:    {clip_results['recall']:.4f}")

# Save checkpoint
#torch.save(trained_clip.state_dict(), os.path.join(OUTPUT_DIR, 'clip_stance.pt'))
#print(f"  Checkpoint saved: {OUTPUT_DIR}/clip_stance.pt")

del trained_clip, clip_model
torch.cuda.empty_cache()
# Out:
# MODEL 1: CLIP
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
#   CLIP encoder partially frozen (last layer + classifier trainable)
#   CLIP initialized: hidden_dim=512 | num_classes=2
#   Total params: 151,409,155
#   Trainable:    71,041,027
#
# Training Stance Classification
#   Train batches: 137 | Dev batches: 13
#
# Epoch 1/10
# --------------------------------------------------
# ...
# Validation:   0%|          | 0/13 [00:00<?, ?it/s]
#   Train Loss: 0.6847
#   Dev Loss: 0.6614 | Dev F1: 0.5889 | LR: 2.00e-05
#    New best F1: 0.5889
#
# Epoch 2/10
# --------------------------------------------------
# Training:   0%|          | 0/137 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ### Model 2: ViT

# %%
print("MODEL 2: ViT")

vit_processor = ViTImageProcessor.from_pretrained(VIT_MODEL)
vit_model = ViTClassifier(model_name=VIT_MODEL, num_classes=2, freeze_encoder=True)

print(f"  Total params: {sum(p.numel() for p in vit_model.parameters()):,}")
print(f"  Trainable:    {sum(p.numel() for p in vit_model.parameters() if p.requires_grad):,}")

trained_vit, vit_history = train_vision_model(
    vit_model, vit_processor, df_train, df_dev,
    num_epochs=NUM_EPOCHS, learning_rate=LEARNING_RATE, batch_size=BATCH_SIZE)

vit_results = evaluate_vision_model(trained_vit, vit_processor, df_test)

all_results.append({'Model': 'ViT', **vit_results})
all_histories['ViT'] = vit_history

print(f"\n ViT Results:")
print(f"  Test F1:        {vit_results['f1']:.4f}")
print(f"  Test Accuracy:  {vit_results['accuracy']:.4f}")
print(f"  Test Precision: {vit_results['precision']:.4f}")
print(f"  Test Recall:    {vit_results['recall']:.4f}")

#torch.save(trained_vit.state_dict(), os.path.join(OUTPUT_DIR, 'vit_stance.pt'))
#print(f"  Checkpoint saved: {OUTPUT_DIR}/vit_stance.pt")

del trained_vit, vit_model
torch.cuda.empty_cache()
# Out:
# MODEL 2: ViT
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([2]) in the model instantiated
# - classifier.weight: found shape torch.Size([1000, 768]) in the checkpoint and torch.Size([2, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   ViT encoder partially frozen (last layer + classifier trainable)
#   ViT initialized: num_classes=2
#   Total params: 85,800,194
#   Trainable:    7,089,410
#
# Training Stance Classification
#   Train batches: 137 | Dev batches: 13
#
# Epoch 1/10
# --------------------------------------------------
# ...
# Validation:   0%|          | 0/13 [00:00<?, ?it/s]
#   Train Loss: 0.6775
#   Dev Loss: 0.6581 | Dev F1: 0.4970 | LR: 2.00e-05
# ...

# %% [markdown]
# ## Model 3: BLIP

# %%
print("MODEL 3: BLIP")

blip_processor = BlipProcessor.from_pretrained(BLIP_MODEL)
blip_model = BLIPClassifier(model_name=BLIP_MODEL, num_classes=2, freeze_encoder=True)

print(f"  Total params: {sum(p.numel() for p in blip_model.parameters()):,}")
print(f"  Trainable:    {sum(p.numel() for p in blip_model.parameters() if p.requires_grad):,}")

trained_blip, blip_history = train_vision_model(
    blip_model, blip_processor, df_train, df_dev,
    num_epochs=NUM_EPOCHS, learning_rate=LEARNING_RATE, batch_size=BATCH_SIZE)

blip_results = evaluate_vision_model(trained_blip, blip_processor, df_test)

all_results.append({'Model': 'BLIP', **blip_results})
all_histories['BLIP'] = blip_history

print(f"\n BLIP Results:")
print(f"  Test F1:        {blip_results['f1']:.4f}")
print(f"  Test Accuracy:  {blip_results['accuracy']:.4f}")
print(f"  Test Precision: {blip_results['precision']:.4f}")
print(f"  Test Recall:    {blip_results['recall']:.4f}")

#torch.save(trained_blip.state_dict(), os.path.join(OUTPUT_DIR, 'blip_stance.pt'))
#print(f"  Checkpoint saved: {OUTPUT_DIR}/blip_stance.pt")

del trained_blip, blip_model
torch.cuda.empty_cache()
# Out:
# MODEL 3: BLIP
# `BlipModel` is going to be deprecated in future release, please use `BlipForConditionalGeneration`, `BlipForQuestionAnswering` or `BlipForImageTextRetrieval` depending on your usecase.
# ...

# %% [markdown]
# ### Model 4: ALIGN

# %%
print("MODEL 4: ALIGN")

align_processor = AlignProcessor.from_pretrained(ALIGN_MODEL)
align_model = ALIGNClassifier(model_name=ALIGN_MODEL, num_classes=2, freeze_encoder=True)

print(f"  Total params: {sum(p.numel() for p in align_model.parameters()):,}")
print(f"  Trainable:    {sum(p.numel() for p in align_model.parameters() if p.requires_grad):,}")

trained_align, align_history = train_vision_model(align_model, align_processor, df_train, df_dev,num_epochs=NUM_EPOCHS, learning_rate=LEARNING_RATE, batch_size=BATCH_SIZE)
align_results = evaluate_vision_model(trained_align, align_processor, df_test)

all_results.append({'Model': 'ALIGN', **align_results})
all_histories['ALIGN'] = align_history

print(f"\n ALIGN Results:")
print(f"  Test F1:        {align_results['f1']:.4f}")
print(f"  Test Accuracy:  {align_results['accuracy']:.4f}")
print(f"  Test Precision: {align_results['precision']:.4f}")
print(f"  Test Recall:    {align_results['recall']:.4f}")

#torch.save(trained_align.state_dict(), os.path.join(OUTPUT_DIR, 'align_stance.pt'))
#print(f"  Checkpoint saved: {OUTPUT_DIR}/align_stance.pt")

del trained_align, align_model
torch.cuda.empty_cache()
# Out:
# MODEL 4: ALIGN
#   ALIGN encoder partially frozen (last stage + classifier trainable)
#   ALIGN initialized: hidden_dim=640 | num_classes=2
#   Total params: 62,308,050
#   Trainable:    164,610
#
# Training Stance Classification
#   Train batches: 137 | Dev batches: 13
#
# Epoch 1/10
# --------------------------------------------------
# ...
# Validation:   0%|          | 0/13 [00:00<?, ?it/s]
#   Train Loss: 0.6872
#   Dev Loss: 0.6763 | Dev F1: 0.3200 | LR: 2.00e-05
#    New best F1: 0.3200
#
# Epoch 2/10
# --------------------------------------------------
# ...
# Validation:   0%|          | 0/13 [00:00<?, ?it/s]
#   Train Loss: 0.6784
#   Dev Loss: 0.6748 | Dev F1: 0.4098 | LR: 1.78e-05
#    New best F1: 0.4098
#
# Epoch 3/10
# --------------------------------------------------
# Training:   0%|          | 0/137 [00:00<?, ?it/s]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7febcc43d870>
# Traceback (most recent call last):
# ...

# %% [markdown]
# ## Results

# %%
# Build results DataFrame
results_df = pd.DataFrame([{
        'Model':r['Model'],
        'F1':r['f1'],
        'Accuracy':r['accuracy'],
        'Precision':r['precision'],
        'Recall':r['recall']} 
        for r in all_results])

results_df = results_df.sort_values('F1', ascending=False).reset_index(drop=True)


# Save results
results_df.to_csv(os.path.join(OUTPUT_DIR, 'vision_models_stance_results.csv'), index=False)
print(f"\n Results saved to: {OUTPUT_DIR}/vision_models_stance_results.csv")
results_df.head()
# Out:
#  Results saved to: results/vision/advanced_vision_models//vision_models_stance_results.csv
#    Model        F1  Accuracy  Precision    Recall
# 0   CLIP  0.628099  0.700000   0.612903  0.644068
# 1  ALIGN  0.588235  0.650000   0.547445  0.635593
# 2   BLIP  0.581818  0.693333   0.627451  0.542373
# 3    ViT  0.465517  0.586667   0.473684  0.457627

# %% [markdown]
# ## Visualizations

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# F1 Score comparison
ax = axes[0, 0]
colors = sns.color_palette("husl", len(results_df))
bars = ax.bar(results_df['Model'], results_df['F1'], color=colors, alpha=0.8)
ax.set_ylabel('F1 Score', fontweight='bold')
ax.set_title('F1 Score by Model', fontweight='bold', fontsize=12)
ax.set_ylim(0, 1)
ax.grid(axis='y', alpha=0.3)
for bar, val in zip(bars, results_df['F1']):
    ax.text(bar.get_x() + bar.get_width()/2, val + 0.02, f'{val:.4f}',
            ha='center', va='bottom', fontsize=10, fontweight='bold')

# Metrics comparison
ax = axes[0, 1]
x = np.arange(len(results_df))
width = 0.25
ax.bar(x - width, results_df['Precision'], width, label='Precision', alpha=0.8)
ax.bar(x, results_df['Recall'], width, label='Recall', alpha=0.8)
ax.bar(x + width, results_df['F1'], width, label='F1', alpha=0.8)
ax.set_xticks(x)
ax.set_xticklabels(results_df['Model'])
ax.set_ylabel('Score', fontweight='bold')
ax.set_title('Precision, Recall, F1 Comparison', fontweight='bold', fontsize=12)
ax.set_ylim(0, 1)
ax.legend()
ax.grid(axis='y', alpha=0.3)

# Training curves (F1)
ax = axes[1, 0]
for model_name, history in all_histories.items():
    ax.plot(history['dev_f1'], marker='o', markersize=3, label=model_name, linewidth=2)
ax.set_xlabel('Epoch', fontweight='bold')
ax.set_ylabel('Dev F1', fontweight='bold')
ax.set_title('Training Curves: Dev F1', fontweight='bold', fontsize=12)
ax.legend()
ax.grid(alpha=0.3)

# Confusion matrices
ax = axes[1, 1]
ax.axis('off')
ax.text(0.5, 0.9, 'Confusion Matrices', ha='center', va='top',
        transform=ax.transAxes, fontsize=12, fontweight='bold')

for i, r in enumerate(all_results):
    cm_text = f"{r['Model']}:\n"
    cm_text += f"  TN={r['confusion_matrix'][0,0]}  FP={r['confusion_matrix'][0,1]}\n"
    cm_text += f"  FN={r['confusion_matrix'][1,0]}  TP={r['confusion_matrix'][1,1]}"
    ax.text(0.1, 0.75 - i*0.2, cm_text, ha='left', va='top',
            transform=ax.transAxes, fontsize=9, fontfamily='monospace')

plt.suptitle('Vision Models Benchmark: Stance Classification',
             fontsize=14, fontweight='bold', y=0.995)
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, 'vision_models_comparison.png'), dpi=150, bbox_inches='tight')
plt.show()

print(f"\n Visualization saved to: {OUTPUT_DIR}/vision_models_comparison.png")
# Out:
#  Visualization saved to: results/vision/advanced_vision_models//vision_models_comparison.png
